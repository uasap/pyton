# %%
import pandas as pd

# %%
df = pd.read_csv("laptopPrice.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.brand[max(df.brand.value_counts())]
# Out:
# 'DELL'

# %%
max(df.brand.value_counts())
# Out:
# 249

# %%
#3.2 Какая минимальная и максимальная стоимость у ноутбуков в данных?
print(f"Самый дорогой ноут имеет цену  {df.Price.max()}" )
print(f"Самый дешевый ноут имеет цену  {df.Price.min()}" )
# Out:
# Самый дорогой ноут имеет цену  441990
# Самый дешевый ноут имеет цену  16990

# %%
# 3.3 Какой самый дорогой ноутбук в данных?
# Выведите все характеристики только по этому ноутбуку
# Если таких ноутбуков несколько, то выводите их всех
df[df.Price == df.Price.max() ]
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 594  ASUS           Intel        Core i9            11th  16 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb  weight warranty  \
# 594  3072 GB  0 GB  Windows  32-bit            6 GB  Casual   1 year
#
#     Touchscreen msoffice   Price   rating  Number of Ratings  \
# 594          No       No  441990  5 stars                  1
#
#      Number of Reviews
# 594                  1

# %%
int("1024 GB".split()[0])
# Out:
# 1024

# %%
def get_size(row):
    return int(row["hdd"].split()[0])

# %%
df["hdd"] = df.apply(get_size,axis=1)

# %%
df[df.hdd == df.hdd.min()][["brand","processor_name","hdd", "Price"]]
# Out:
#       brand processor_name  hdd   Price
# 3      ASUS        Core i5    0   69990
# 14     ASUS        Core i3    0   35990
# 15       HP        Core i3    0   56490
# 16       HP        Core i5    0   65390
# 17   Lenovo   Celeron Dual    0   31999
# ..      ...            ...  ...     ...
# 818    ASUS        Ryzen 9    0  135990
# 819    ASUS        Ryzen 9    0  144990
# 820    ASUS        Ryzen 9    0  149990
# 821    ASUS        Ryzen 9    0  142990
# 822  Lenovo        Ryzen 5    0   57490
#
# [621 rows x 4 columns]

# %%
max_HP = df[df["brand"] == "HP"]["Price"].max()  #Сколько стоит самый дорогой ноутбук у компании HP?


df[ (df["brand"] == "HP") & (df.Price == max_HP)   ]
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 507    HP           Intel        Core i7            10th  16 GB   LPDDR3
#
#         ssd  hdd       os  os_bit graphic_card_gb  weight warranty  \
# 507  512 GB    0  Windows  64-bit            0 GB  Casual   1 year
#
#     Touchscreen msoffice   Price   rating  Number of Ratings  \
# 507         Yes      Yes  239759  3 stars                  0
#
#      Number of Reviews
# 507                  0

# %%
m = df.Price.median()
df [ (df.rating == "4 stars") & (df.ram_gb == "8 GB") & (df.Price<= m*1.1)]
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 18       HP           Intel   Celeron Dual   Not Available   8 GB     DDR4
# 25   Lenovo           Intel        Core i3            10th   8 GB     DDR4
# 27     ASUS           Intel        Core i3            10th   8 GB     DDR4
# 28       HP           Intel        Core i3            11th   8 GB     DDR4
# 29     DELL           Intel        Core i3            10th   8 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 731  Lenovo             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 732    ASUS             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 733    ASUS             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 734  Lenovo             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
### задача 4.3
##4.3 Как много ноутбуков с 4 звездами рейтинга и  с 8GB RAM и по цене не больше 110 % от медианной цены?
count = df [ (df.rating == "4 stars") & (df.ram_gb == "8 GB") & (df.Price<= m*1.1)].shape[0]
print(f"Процент хороших и недорогих ноуток к общему количеству составляет {round(count / df.shape[0]*100,2)} %")
# Out:
# Процент хороших и недорогих ноуток к общему количеству составляет 22.72 %
